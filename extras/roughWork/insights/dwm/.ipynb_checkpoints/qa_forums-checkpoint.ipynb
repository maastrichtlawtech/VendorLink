# %% [markdown]
# # Loading the dataset

# %%
import os

from collections import Counter
from textblob import TextBlob 

import numpy as np
import pandas as pd

import nltk
from nltk.probability import FreqDist

import plotly
import plotly.graph_objects as go
import plotly.figure_factory as ff

# %% [markdown]
# # Loading the data

# %%
df = pd.read_csv("forums.csv", error_bad_lines=False)

# %%
for column in ['description', 'paragraphs', 'headings', 'listings', 'link-text']:
    df[column] = df[column].apply(lambda x : eval(x))

# %% [markdown]
# Paragraphs

# %%
paragraphs = list(df['paragraphs'])
paragraphs = [para for para in paragraphs if para!=None]
print("No of paragraphs:", len(paragraphs))

# Cleaning paragraphs
paragraphs = [[para for para in paras if "»" not in para] for paras in paragraphs]
paragraphs = [item for sublist in paragraphs for item in sublist]
paragraphs = [para.split(" ") for para in paragraphs]
paragraphs_len = [len(para) for para in paragraphs]
# Out:
# No of paragraphs: 937

# %%
paragraphs
# Out:
# [['return', 'to', '“art,', 'photoshopped,', 'shotacon,', '3d”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['code:', 'select', 'all'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', '“tv', 'shows”'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“documentary', 'films”'],
#  ['privacy|terms'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['skip', 'to', 'content'],
#  ['privacy|terms'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“announcements”'],
#  ['it', 'is', 'currently', 'sun', 'may', '03,', '2020', '11:30'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['total',
#   'posts',
#   '429325',
#   '•',
#   'total',
#   'topics',
#   '23388',
#   '•',
#   'total',
#   'members',
#   '228738',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'bertram',
#   'balls'],
#  ['return', 'to', '“webcam”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', '“tv', 'shows”'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', '“tv', 'shows”'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['code:', 'select', 'all'],
#  ['privacy|terms'],
#  ['return', 'to', '“movie', 'clips”'],
#  ['it', 'is', 'currently', 'sun', 'may', '03,', '2020', '11:30'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['total',
#   'posts',
#   '429325',
#   '•',
#   'total',
#   'topics',
#   '23388',
#   '•',
#   'total',
#   'members',
#   '228738',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'bertram',
#   'balls'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', '“tv', 'shows”'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“allowed', 'hosts”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['it', 'is', 'currently', 'sun', 'may', '03,', '2020', '11:30'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['total',
#   'posts',
#   '429325',
#   '•',
#   'total',
#   'topics',
#   '23388',
#   '•',
#   'total',
#   'members',
#   '228738',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'bertram',
#   'balls'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['skip', 'to', 'content'],
#  ['privacy|terms'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', '“.gif', 'all', 'sections”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“movie', 'clips”'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“movie', 'clips”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['as',
#   'a',
#   'forum',
#   'user',
#   'you',
#   'must',
#   'comply',
#   'with',
#   'boystown.',
#   'by',
#   'doing',
#   'that,',
#   'we',
#   'can',
#   'provide',
#   'a',
#   'smooth,',
#   'fun',
#   'and',
#   'productive',
#   'experience',
#   'for',
#   'all',
#   'of',
#   'our',
#   'community.',
#   'failure',
#   'to',
#   'do',
#   'so',
#   'may',
#   'result',
#   'in',
#   'temporary',
#   'or',
#   'permanent',
#   'exclusion',
#   'of',
#   'your',
#   'account.'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['code:', 'select', 'all'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['total',
#   'posts',
#   '412944',
#   '•',
#   'total',
#   'topics',
#   '22697',
#   '•',
#   'total',
#   'members',
#   '225195',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'zvmal123'],
#  ['privacy|terms'],
#  ['it', 'is', 'currently', 'fri', 'apr', '10,', '2020', '6:20'],
#  ['return', 'to', '“non-nude”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', '“tv', 'shows”'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['return', 'to', '“spycam', 'pics', '(photo)”'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['it', 'is', 'currently', 'sun', 'may', '03,', '2020', '11:30'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['total',
#   'posts',
#   '429325',
#   '•',
#   'total',
#   'topics',
#   '23388',
#   '•',
#   'total',
#   'members',
#   '228738',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'bertram',
#   'balls'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“naturist', '/', 'nude', '(photo)”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['by',
#   'accessing',
#   '“boystown”',
#   '(hereinafter',
#   '“we”,',
#   '“us”,',
#   '“our”,',
#   '“boystown”,',
#   '“http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion”),',
#   'you',
#   'agree',
#   'to',
#   'be',
#   'legally',
#   'bound',
#   'by',
#   'the',
#   'following',
#   'terms.',
#   'if',
#   'you',
#   'do',
#   'not',
#   'agree',
#   'to',
#   'be',
#   'legally',
#   'bound',
#   'by',
#   'all',
#   'of',
#   'the',
#   'following',
#   'terms',
#   'then',
#   'please',
#   'do',
#   'not',
#   'access',
#   'and/or',
#   'use',
#   '“boystown”.',
#   'we',
#   'may',
#   'change',
#   'these',
#   'at',
#   'any',
#   'time',
#   'and',
#   'we’ll',
#   'do',
#   'our',
#   'utmost',
#   'in',
#   'informing',
#   'you,',
#   'though',
#   'it',
#   'would',
#   'be',
#   'prudent',
#   'to',
#   'review',
#   'this',
#   'regularly',
#   'yourself',
#   'as',
#   'your',
#   'continued',
#   'usage',
#   'of',
#   '“boystown”',
#   'after',
#   'changes',
#   'mean',
#   'you',
#   'agree',
#   'to',
#   'be',
#   'legally',
#   'bound',
#   'by',
#   'these',
#   'terms',
#   'as',
#   'they',
#   'are',
#   'updated',
#   'and/or',
#   'amended.our',
#   'forums',
#   'are',
#   'powered',
#   'by',
#   'phpbb',
#   '(hereinafter',
#   '“they”,',
#   '“them”,',
#   '“their”,',
#   '“phpbb',
#   'software”,',
#   '“www.phpbb.com”,',
#   '“phpbb',
#   'limited”,',
#   '“phpbb',
#   'teams”)',
#   'which',
#   'is',
#   'a',
#   'bulletin',
#   'board',
#   'solution',
#   'released',
#   'under',
#   'the',
#   '“gnu',
#   'general',
#   'public',
#   'license',
#   'v2”',
#   '(hereinafter',
#   '“gpl”)',
#   'and',
#   'can',
#   'be',
#   'downloaded',
#   'from',
#   'www.phpbb.com.',
#   'the',
#   'phpbb',
#   'software',
#   'only',
#   'facilitates',
#   'internet',
#   'based',
#   'discussions;',
#   'phpbb',
#   'limited',
#   'is',
#   'not',
#   'responsible',
#   'for',
#   'what',
#   'we',
#   'allow',
#   'and/or',
#   'disallow',
#   'as',
#   'permissible',
#   'content',
#   'and/or',
#   'conduct.',
#   'for',
#   'further',
#   'information',
#   'about',
#   'phpbb,',
#   'please',
#   'see:',
#   'https://www.phpbb.com/.you',
#   'agree',
#   'not',
#   'to',
#   'post',
#   'any',
#   'abusive,',
#   'obscene,',
#   'vulgar,',
#   'slanderous,',
#   'hateful,',
#   'threatening,',
#   'sexually-orientated',
#   'or',
#   'any',
#   'other',
#   'material',
#   'that',
#   'may',
#   'violate',
#   'any',
#   'laws',
#   'be',
#   'it',
#   'of',
#   'your',
#   'country,',
#   'the',
#   'country',
#   'where',
#   '“boystown”',
#   'is',
#   'hosted',
#   'or',
#   'international',
#   'law.',
#   'doing',
#   'so',
#   'may',
#   'lead',
#   'to',
#   'you',
#   'being',
#   'immediately',
#   'and',
#   'permanently',
#   'banned,',
#   'with',
#   'notification',
#   'of',
#   'your',
#   'internet',
#   'service',
#   'provider',
#   'if',
#   'deemed',
#   'required',
#   'by',
#   'us.',
#   'the',
#   'ip',
#   'address',
#   'of',
#   'all',
#   'posts',
#   'are',
#   'recorded',
#   'to',
#   'aid',
#   'in',
#   'enforcing',
#   'these',
#   'conditions.',
#   'you',
#   'agree',
#   'that',
#   '“boystown”',
#   'have',
#   'the',
#   'right',
#   'to',
#   'remove,',
#   'edit,',
#   'move',
#   'or',
#   'close',
#   'any',
#   'topic',
#   'at',
#   'any',
#   'time',
#   'should',
#   'we',
#   'see',
#   'fit.',
#   'as',
#   'a',
#   'user',
#   'you',
#   'agree',
#   'to',
#   'any',
#   'information',
#   'you',
#   'have',
#   'entered',
#   'to',
#   'being',
#   'stored',
#   'in',
#   'a',
#   'database.',
#   'while',
#   'this',
#   'information',
#   'will',
#   'not',
#   'be',
#   'disclosed',
#   'to',
#   'any',
#   'third',
#   'party',
#   'without',
#   'your',
#   'consent,',
#   'neither',
#   '“boystown”',
#   'nor',
#   'phpbb',
#   'shall',
#   'be',
#   'held',
#   'responsible',
#   'for',
#   'any',
#   'hacking',
#   'attempt',
#   'that',
#   'may',
#   'lead',
#   'to',
#   'the',
#   'data',
#   'being',
#   'compromised.'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['by',
#   'accessing',
#   '“boystown”',
#   '(hereinafter',
#   '“we”,',
#   '“us”,',
#   '“our”,',
#   '“boystown”,',
#   '“http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion”),',
#   'you',
#   'agree',
#   'to',
#   'be',
#   'legally',
#   'bound',
#   'by',
#   'the',
#   'following',
#   'terms.',
#   'if',
#   'you',
#   'do',
#   'not',
#   'agree',
#   'to',
#   'be',
#   'legally',
#   'bound',
#   'by',
#   'all',
#   'of',
#   'the',
#   'following',
#   'terms',
#   'then',
#   'please',
#   'do',
#   'not',
#   'access',
#   'and/or',
#   'use',
#   '“boystown”.',
#   'we',
#   'may',
#   'change',
#   'these',
#   'at',
#   'any',
#   'time',
#   'and',
#   'we’ll',
#   'do',
#   'our',
#   'utmost',
#   'in',
#   'informing',
#   'you,',
#   'though',
#   'it',
#   'would',
#   'be',
#   'prudent',
#   'to',
#   'review',
#   'this',
#   'regularly',
#   'yourself',
#   'as',
#   'your',
#   'continued',
#   'usage',
#   'of',
#   '“boystown”',
#   'after',
#   'changes',
#   'mean',
#   'you',
#   'agree',
#   'to',
#   'be',
#   'legally',
#   'bound',
#   'by',
#   'these',
#   'terms',
#   'as',
#   'they',
#   'are',
#   'updated',
#   'and/or',
#   'amended.our',
#   'forums',
#   'are',
#   'powered',
#   'by',
#   'phpbb',
#   '(hereinafter',
#   '“they”,',
#   '“them”,',
#   '“their”,',
#   '“phpbb',
#   'software”,',
#   '“www.phpbb.com”,',
#   '“phpbb',
#   'limited”,',
#   '“phpbb',
#   'teams”)',
#   'which',
#   'is',
#   'a',
#   'bulletin',
#   'board',
#   'solution',
#   'released',
#   'under',
#   'the',
#   '“gnu',
#   'general',
#   'public',
#   'license',
#   'v2”',
#   '(hereinafter',
#   '“gpl”)',
#   'and',
#   'can',
#   'be',
#   'downloaded',
#   'from',
#   'www.phpbb.com.',
#   'the',
#   'phpbb',
#   'software',
#   'only',
#   'facilitates',
#   'internet',
#   'based',
#   'discussions;',
#   'phpbb',
#   'limited',
#   'is',
#   'not',
#   'responsible',
#   'for',
#   'what',
#   'we',
#   'allow',
#   'and/or',
#   'disallow',
#   'as',
#   'permissible',
#   'content',
#   'and/or',
#   'conduct.',
#   'for',
#   'further',
#   'information',
#   'about',
#   'phpbb,',
#   'please',
#   'see:',
#   'https://www.phpbb.com/.you',
#   'agree',
#   'not',
#   'to',
#   'post',
#   'any',
#   'abusive,',
#   'obscene,',
#   'vulgar,',
#   'slanderous,',
#   'hateful,',
#   'threatening,',
#   'sexually-orientated',
#   'or',
#   'any',
#   'other',
#   'material',
#   'that',
#   'may',
#   'violate',
#   'any',
#   'laws',
#   'be',
#   'it',
#   'of',
#   'your',
#   'country,',
#   'the',
#   'country',
#   'where',
#   '“boystown”',
#   'is',
#   'hosted',
#   'or',
#   'international',
#   'law.',
#   'doing',
#   'so',
#   'may',
#   'lead',
#   'to',
#   'you',
#   'being',
#   'immediately',
#   'and',
#   'permanently',
#   'banned,',
#   'with',
#   'notification',
#   'of',
#   'your',
#   'internet',
#   'service',
#   'provider',
#   'if',
#   'deemed',
#   'required',
#   'by',
#   'us.',
#   'the',
#   'ip',
#   'address',
#   'of',
#   'all',
#   'posts',
#   'are',
#   'recorded',
#   'to',
#   'aid',
#   'in',
#   'enforcing',
#   'these',
#   'conditions.',
#   'you',
#   'agree',
#   'that',
#   '“boystown”',
#   'have',
#   'the',
#   'right',
#   'to',
#   'remove,',
#   'edit,',
#   'move',
#   'or',
#   'close',
#   'any',
#   'topic',
#   'at',
#   'any',
#   'time',
#   'should',
#   'we',
#   'see',
#   'fit.',
#   'as',
#   'a',
#   'user',
#   'you',
#   'agree',
#   'to',
#   'any',
#   'information',
#   'you',
#   'have',
#   'entered',
#   'to',
#   'being',
#   'stored',
#   'in',
#   'a',
#   'database.',
#   'while',
#   'this',
#   'information',
#   'will',
#   'not',
#   'be',
#   'disclosed',
#   'to',
#   'any',
#   'third',
#   'party',
#   'without',
#   'your',
#   'consent,',
#   'neither',
#   '“boystown”',
#   'nor',
#   'phpbb',
#   'shall',
#   'be',
#   'held',
#   'responsible',
#   'for',
#   'any',
#   'hacking',
#   'attempt',
#   'that',
#   'may',
#   'lead',
#   'to',
#   'the',
#   'data',
#   'being',
#   'compromised.'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“announcements”'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['return', 'to', '“.gif', 'all', 'sections”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“short', 'films”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['are',
#   'you',
#   'sure',
#   'you',
#   'want',
#   'to',
#   'delete',
#   'all',
#   'cookies',
#   'set',
#   'by',
#   'this',
#   'board?'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['code:', 'select', 'all'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“models', '(photo)”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', '“tv', 'shows”'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“music', 'videos”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“documentary', 'films”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“allowed', 'hosts”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“announcements”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“chat”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['code:', 'select', 'all'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“short', 'films”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“short', 'films”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', '“tv', 'shows”'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“short', 'films”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['it', 'is', 'currently', 'sun', 'may', '03,', '2020', '11:30'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['total',
#   'posts',
#   '429325',
#   '•',
#   'total',
#   'topics',
#   '23388',
#   '•',
#   'total',
#   'members',
#   '228738',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'bertram',
#   'balls'],
#  ['it', 'is', 'currently', 'sun', 'may', '03,', '2020', '11:30'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['total',
#   'posts',
#   '429325',
#   '•',
#   'total',
#   'topics',
#   '23388',
#   '•',
#   'total',
#   'members',
#   '228738',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'bertram',
#   'balls'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['total',
#   'posts',
#   '575887',
#   '•',
#   'total',
#   'topics',
#   '30158',
#   '•',
#   'total',
#   'members',
#   '296322',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'undressfuckrepeat'],
#  ['it', 'is', 'currently', 'wed', 'jul', '01,', '2020', '16:43'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“rules”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
# ...
#   'with',
#   'notification',
#   'of',
#   'your',
#   'internet',
#   'service',
#   'provider',
#   'if',
#   'deemed',
#   'required',
#   'by',
#   'us.',
#   'the',
#   'ip',
#   'address',
#   'of',
#   'all',
#   'posts',
#   'are',
#   'recorded',
#   'to',
#   'aid',
#   'in',
#   'enforcing',
#   'these',
#   'conditions.',
#   'you',
#   'agree',
#   'that',
#   '“boystown”',
#   'have',
#   'the',
#   'right',
#   'to',
#   'remove,',
#   'edit,',
#   'move',
#   'or',
#   'close',
#   'any',
#   'topic',
#   'at',
#   'any',
#   'time',
#   'should',
#   'we',
#   'see',
#   'fit.',
#   'as',
#   'a',
#   'user',
#   'you',
#   'agree',
#   'to',
#   'any',
#   'information',
#   'you',
#   'have',
#   'entered',
#   'to',
#   'being',
#   'stored',
#   'in',
#   'a',
#   'database.',
#   'while',
#   'this',
#   'information',
#   'will',
#   'not',
#   'be',
#   'disclosed',
#   'to',
#   'any',
#   'third',
#   'party',
#   'without',
#   'your',
#   'consent,',
#   'neither',
#   '“boystown”',
#   'nor',
#   'phpbb',
#   'shall',
#   'be',
#   'held',
#   'responsible',
#   'for',
#   'any',
#   'hacking',
#   'attempt',
#   'that',
#   'may',
#   'lead',
#   'to',
#   'the',
#   'data',
#   'being',
#   'compromised.'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['where',
#   'boys',
#   'go',
#   'for',
#   'a',
#   'good',
#   'timehttp://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion/'],
#  ['http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion/viewtopic.php?f=6&t=170'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“adolescents', '(photo)”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“documentary', 'films”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['code:', 'select', 'all'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['privacy|terms'],
#  ['it', 'is', 'currently', 'sun', 'may', '03,', '2020', '11:30'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['total',
#   'posts',
#   '429325',
#   '•',
#   'total',
#   'topics',
#   '23388',
#   '•',
#   'total',
#   'members',
#   '228738',
#   '•',
#   'our',
#   'newest',
#   'member',
#   'bertram',
#   'balls'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“movie', 'clips”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“announcements”'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['in',
#   'order',
#   'to',
#   'login',
#   'you',
#   'must',
#   'be',
#   'registered.',
#   'registering',
#   'takes',
#   'only',
#   'a',
#   'few',
#   'moments',
#   'but',
#   'gives',
#   'you',
#   'increased',
#   'capabilities.',
#   'the',
#   'board',
#   'administrator',
#   'may',
#   'also',
#   'grant',
#   'additional',
#   'permissions',
#   'to',
#   'registered',
#   'users.',
#   'before',
#   'you',
#   'register',
#   'please',
#   'ensure',
#   'you',
#   'are',
#   'familiar',
#   'with',
#   'our',
#   'terms',
#   'of',
#   'use',
#   'and',
#   'related',
#   'policies.',
#   'please',
#   'ensure',
#   'you',
#   'read',
#   'any',
#   'forum',
#   'rules',
#   'as',
#   'you',
#   'navigate',
#   'around',
#   'the',
#   'board.'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['terms', 'of', 'use', '|', 'privacy', 'policy'],
#  ['register'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“documentary', 'films”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“allowed', 'hosts”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“movie', 'clips”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“models', '(photo)”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“movies”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['return', 'to', '“fetish', '(photo)”'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['return', 'to', '“tv', 'series”'],
#  ['privacy|terms'],
#  ['skip', 'to', 'content'],
#  ['where', 'boys', 'go', 'for', 'a', 'good', 'time'],
#  ['return', 'to', 'board', 'index'],
#  ['powered',
#   'by',
#   'phpbb:registered:',
#   'forum',
#   'software',
#   ':copyright:',
#   'phpbb',
#   'limited'],
#  ['privacy|terms'],
#  ['you',
#   'cannot',
#   'post',
#   'new',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'reply',
#   'to',
#   'topics',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'edit',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forumyou',
#   'cannot',
#   'delete',
#   'your',
#   'posts',
#   'in',
#   'this',
#   'forum'],
#  ['skip', 'to', 'content'],
#  ...]

# %%
Counter(paragraphs_len)
# Out:
# Counter({6: 191,
#          3: 1099,
#          7: 941,
#          8: 997,
#          1: 1113,
#          4: 456,
#          29: 157,
#          59: 176,
#          17: 51,
#          5: 17,
#          40: 4,
#          16: 8,
#          306: 22,
#          13: 12,
#          455: 9,
#          19: 1,
#          23: 5,
#          45: 1})

# %%
paragraphs = [" ".join(para) for para in paragraphs]
paragraphs = [para for para in paragraphs if "• total topics" not in para]

# %%
print("Number of paragraphs left:", len(set(paragraphs)))
set(paragraphs)
# Out:
# Number of paragraphs left: 74
# {'are you sure you want to delete all cookies set by this board?',
#  'as a forum user you must comply with boystown. by doing that, we can provide a smooth, fun and productive experience for all of our community. failure to do so may result in temporary or permanent exclusion of your account.',
#  'by accessing “boystown” (hereinafter “we”, “us”, “our”, “boystown”, “http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion”), you agree to be legally bound by the following terms. if you do not agree to be legally bound by all of the following terms then please do not access and/or use “boystown”. we may change these at any time and we’ll do our utmost in informing you, though it would be prudent to review this regularly yourself as your continued usage of “boystown” after changes mean you agree to be legally bound by these terms as they are updated and/or amended.our forums are powered by phpbb (hereinafter “they”, “them”, “their”, “phpbb software”, “www.phpbb.com”, “phpbb limited”, “phpbb teams”) which is a bulletin board solution released under the “gnu general public license v2” (hereinafter “gpl”) and can be downloaded from www.phpbb.com. the phpbb software only facilitates internet based discussions; phpbb limited is not responsible for what we allow and/or disallow as permissible content and/or conduct. for further information about phpbb, please see: https://www.phpbb.com/.you agree not to post any abusive, obscene, vulgar, slanderous, hateful, threatening, sexually-orientated or any other material that may violate any laws be it of your country, the country where “boystown” is hosted or international law. doing so may lead to you being immediately and permanently banned, with notification of your internet service provider if deemed required by us. the ip address of all posts are recorded to aid in enforcing these conditions. you agree that “boystown” have the right to remove, edit, move or close any topic at any time should we see fit. as a user you agree to any information you have entered to being stored in a database. while this information will not be disclosed to any third party without your consent, neither “boystown” nor phpbb shall be held responsible for any hacking attempt that may lead to the data being compromised.',
#  'code: select all',
#  'creating a new account is currently not possible.',
#  'http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion/viewtopic.php?f=4&t=12535',
#  'http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion/viewtopic.php?f=6&t=170',
#  'http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion/viewtopic.php?f=6&t=171',
#  'http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion/viewtopic.php?f=87&t=23674',
#  'http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion/viewtopic.php?f=87&t=25326',
#  'in order to login you must be registered. registering takes only a few moments but gives you increased capabilities. the board administrator may also grant additional permissions to registered users. before you register please ensure you are familiar with our terms of use and related policies. please ensure you read any forum rules as you navigate around the board.',
#  'it is currently fri apr 10, 2020 6:20',
#  'it is currently mon mar 30, 2020 16:04',
#  'it is currently mon nov 23, 2020 13:58',
#  'it is currently sun may 03, 2020 11:30',
#  'it is currently tue aug 18, 2020 16:59',
#  'it is currently wed dec 30, 2020 15:36',
#  'it is currently wed jul 01, 2020 16:43',
#  'language:british englishfrançaisdeutsch (du)русскийespañol (tú)',
#  'poll runs till fri may 08, 2020 20:45please note that results are sorted by decreasing number of votes received.',
#  'powered by phpbb:registered: forum software :copyright: phpbb limited',
#  'privacy|terms',
#  'register',
#  'return to board index',
#  'return to “.gif all sections”',
#  'return to “adolescents (photo)”',
#  'return to “adolescents”',
#  'return to “allowed hosts”',
#  'return to “announcements”',
#  'return to “art, photoshopped, shotacon, 3d (photo)”',
#  'return to “art, photoshopped, shotacon, 3d”',
#  'return to “chat”',
#  'return to “documentary films”',
#  'return to “fetish (photo)”',
#  'return to “fetish”',
#  'return to “hardcore”',
#  'return to “libera”',
#  'return to “links”',
#  'return to “literature”',
#  'return to “models (photo)”',
#  'return to “movie and subtitle requests”',
#  'return to “movie clips”',
#  'return to “movies”',
#  'return to “music videos”',
#  'return to “naturist / nude (photo)”',
#  'return to “naturist / nude”',
#  'return to “news and current information”',
#  'return to “non-nude (photo)”',
#  'return to “non-nude”',
#  'return to “pedomom”',
#  'return to “photo requests”',
#  'return to “polls”',
#  'return to “rules”',
#  'return to “short films”',
#  'return to “softcore (photo)”',
#  'return to “softcore”',
#  'return to “spycam pics (photo)”',
#  'return to “spycams”',
#  'return to “suggestions and support”',
#  'return to “tech forum”',
#  'return to “themed photo collections”',
#  'return to “toddlers (photo)”',
#  'return to “tv series”',
#  'return to “tv shows”',
#  'return to “video requests”',
#  'return to “webcam”',
#  'skip to content',
#  'terms of use | privacy policy',
#  'these rules are disclosed to clarify the various responsibilities of all community members here on boystown. they shall be adhered to by everyone to ensure that our board runs smoothly and provides a fun and productive experience for all of our community members and visitors.',
#  'this policy explains in detail how “boystown” along with its affiliated companies (hereinafter “we”, “us”, “our”, “boystown”, “http://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion”) and phpbb (hereinafter “they”, “them”, “their”, “phpbb software”, “www.phpbb.com”, “phpbb limited”, “phpbb teams”) use any information collected during any session of usage by you (hereinafter “your information”).your information is collected via two ways. firstly, by browsing “boystown” will cause the phpbb software to create a number of cookies, which are small text files that are downloaded on to your computer’s web browser temporary files. the first two cookies just contain a user identifier (hereinafter “user-id”) and an anonymous session identifier (hereinafter “session-id”), automatically assigned to you by the phpbb software. a third cookie will be created once you have browsed topics within “boystown” and is used to store which topics have been read, thereby improving your user experience.we may also create cookies external to the phpbb software whilst browsing “boystown”, though these are outside the scope of this document which is intended to only cover the pages created by the phpbb software. the second way in which we collect your information is by what you submit to us. this can be, and is not limited to: posting as an anonymous user (hereinafter “anonymous posts”), registering on “boystown” (hereinafter “your account”) and posts submitted by you after registration and whilst logged in (hereinafter “your posts”).your account will at a bare minimum contain a uniquely identifiable name (hereinafter “your user name”), a personal password used for logging into your account (hereinafter “your password”) and a personal, valid email address (hereinafter “your email”). your information for your account at “boystown” is protected by data-protection laws applicable in the country that hosts us. any information beyond your user name, your password, and your email address required by “boystown” during the registration process is either mandatory or optional, at the discretion of “boystown”. in all cases, you have the option of what information in your account is publicly displayed. furthermore, within your account, you have the option to opt-in or opt-out of automatically generated emails from the phpbb software.your password is ciphered (a one-way hash) so that it is secure. however, it is recommended that you do not reuse the same password across a number of different websites. your password is the means of accessing your account at “boystown”, so please guard it carefully and under no circumstance will anyone affiliated with “boystown”, phpbb or another 3rd party, legitimately ask you for your password. should you forget your password for your account, you can use the “i forgot my password” feature provided by the phpbb software. this process will ask you to submit your user name and your email, then the phpbb software will generate a new password to reclaim your account.',
#  'where boys go for a good time',
#  'where boys go for a good timehttp://2tgix56pui5j63y7bq4bgeekjy4mw57zrnbvuvic2ncbt5gyxei7dcqd.onion/',
#  'you agree to abide by the rules of these forums set forth in the following “rules” section: view the rules of this board',
#  'you cannot post new topics in this forumyou cannot reply to topics in this forumyou cannot edit your posts in this forumyou cannot delete your posts in this forum'}

# %% [markdown]
# Links

# %%
links = list(df['link-text'])

# %% [markdown]
# # Performing Sentimental Analysis using TextBob

# %% [markdown]
# Title

# %%
title_text = list(df["title"])
polarity = []
for title in title_text:
    polarity.append(TextBlob(str(title)).sentiment.polarity)

# %%
positive_polarity = [np.mean(instances) if instances>0 else 0.0 for instances in polarity]
negative_polarity = [np.mean(instances) if instances<0 else 0.0 for instances in polarity]

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=positive_polarity, name="positive", marker_color="blue"))
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=negative_polarity, name="negative", marker_color="red"))
fig.update_layout(
                    title_text='Title Polarity, +ve polarity=' + str(round(np.mean(positive_polarity),4)) + ' ,-ve polarity=' + str(round(np.mean(negative_polarity),4)),
                    xaxis_title="Web pages",
                    yaxis_title="Sentiment"
        )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/sentiment/", "title_polarity.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/sentiment/title_polarity.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/sentiment/title_polarity.pdf.html'

# %% [markdown]
# Description

# %%
description_text = list(df["description"])
polarity = []
for descriptions in description_text:
    temp_polarity = []
    if descriptions != None:
        for description in descriptions:
            temp_polarity.append(TextBlob(str(description)).sentiment.polarity)
    else:
        temp_polarity.append(0.0)
    polarity.append(temp_polarity)

# %%
positive_polarity = [np.mean([positve_instances if positve_instances > 0 else 0.0 for positve_instances in instances]) for instances in polarity]
negative_polarity = [np.mean([negative_instances if negative_instances < 0 else 0.0 for negative_instances in instances]) for instances in polarity]

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=positive_polarity, name="positive", marker_color="blue"))
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=negative_polarity, name="negative", marker_color="red"))
fig.update_layout(
                    title_text='Description Polarity, +ve polarity=' + str(round(np.mean(positive_polarity),4)) + ' ,-ve polarity=' + str(round(np.mean(negative_polarity),4)),
                    xaxis_title="Web pages",
                    yaxis_title="Sentiment"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/sentiment/", "description_polarity.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/sentiment/description_polarity.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/sentiment/description_polarity.pdf.html'

# %% [markdown]
# Paragraphs

# %%
paragraphs_text = list(df["paragraphs"])
polarity = []
for paragraphss in paragraphs_text:
    temp_polarity = []
    if paragraphss != None:
        for paragraphs in paragraphss:
            temp_polarity.append(TextBlob(str(paragraphs)).sentiment.polarity)
    else:
        temp_polarity.append(0.0)
    polarity.append(temp_polarity)

positive_polarity = [np.mean([positve_instances if positve_instances > 0 else 0.0 for positve_instances in instances]) for instances in polarity]
negative_polarity = [np.mean([negative_instances if negative_instances < 0 else 0.0 for negative_instances in instances]) for instances in polarity]

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=positive_polarity, name="positive", marker_color="blue"))
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=negative_polarity, name="negative", marker_color="red"))
fig.update_layout(
                    title_text='Paragraphs Polarity, +ve polarity=' + str(round(np.mean(positive_polarity), 4)) + ' ,-ve polarity=' + str(round(np.mean(negative_polarity),4)),
                    xaxis_title="Web pages",
                    yaxis_title="Sentiment"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/sentiment/", "paragraph_polarity.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/sentiment/paragraph_polarity.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/sentiment/paragraph_polarity.pdf.html'

# %% [markdown]
# Headings

# %%
headings_text = list(df["headings"])
polarity = []
for headings in headings_text:
    temp_polarity = []
    if headings != None:
        for heading in headings:
            temp_polarity.append(TextBlob(str(heading)).sentiment.polarity)
    else:
        temp_polarity.append(0.0)
    polarity.append(temp_polarity)

positive_polarity = [np.mean([positve_instances if positve_instances > 0 else 0.0 for positve_instances in instances]) for instances in polarity]
negative_polarity = [np.mean([negative_instances if negative_instances < 0 else 0.0 for negative_instances in instances]) for instances in polarity]

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=positive_polarity, name="positive", marker_color="blue"))
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=negative_polarity, name="negative", marker_color="red"))
fig.update_layout(
                    title_text='Headings Polarity, +ve polarity=' + str(round(np.mean(positive_polarity),4)) + ' ,-ve polarity=' + str(round(np.mean(negative_polarity), 4)),
                    xaxis_title="Web pages",
                    yaxis_title="Sentiment"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/sentiment/", "heading_polarity.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/sentiment/heading_polarity.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/sentiment/heading_polarity.pdf.html'

# %% [markdown]
# listings

# %%
listings_text = list(df["listings"])
polarity = []
for listings in listings_text:
    temp_polarity = []
    if listings != None:
        for listing in listings:
            temp_polarity.append(TextBlob(str(listing)).sentiment.polarity)
    else:
        temp_polarity.append(0.0)
    polarity.append(temp_polarity)

positive_polarity = [np.mean([positve_instances if positve_instances > 0 else 0.0 for positve_instances in instances]) for instances in polarity]
negative_polarity = [np.mean([negative_instances if negative_instances < 0 else 0.0 for negative_instances in instances]) for instances in polarity]

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=positive_polarity, name="positive", marker_color="blue"))
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=negative_polarity, name="negative", marker_color="red"))
fig.update_layout(
                    title_text='Listings Polarity, +ve polarity=' + str(round(np.mean(positive_polarity),4)) + ' ,-ve polarity=' + str(round(np.mean(negative_polarity),4)),
                    xaxis_title="Web pages",
                    yaxis_title="Sentiment"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/sentiment/", "lisiting_polarity.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/sentiment/lisiting_polarity.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/sentiment/lisiting_polarity.pdf.html'

# %% [markdown]
# Link text

# %%
link_texts_text = list(df["link-text"])
polarity = []
for link_texts in link_texts_text:
    temp_polarity = []
    if link_texts != None:
        for link_text in link_texts:
            temp_polarity.append(TextBlob(str(link_text)).sentiment.polarity)
    else:
        temp_polarity.append(0.0)
    polarity.append(temp_polarity)

positive_polarity = [np.mean([positve_instances if positve_instances > 0 else 0.0 for positve_instances in instances]) for instances in polarity]
negative_polarity = [np.mean([negative_instances if negative_instances < 0 else 0.0 for negative_instances in instances]) for instances in polarity]

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=positive_polarity, name="positive", marker_color="blue"))
fig.add_trace(go.Bar(x=np.array(range(len(polarity))), y=negative_polarity, name="negative", marker_color="red"))
fig.update_layout(
                    title_text='Link_texts Polarity, +ve polarity=' + str(round(np.mean(positive_polarity), 4)) + ' ,-ve polarity=' + str(round(np.mean(negative_polarity), 4)),
                    xaxis_title="Web pages",
                    yaxis_title="Sentiment"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/sentiment/", "link_polarity.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/sentiment/link_polarity.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/sentiment/link_polarity.pdf.html'

# %% [markdown]
# # Average Sentence length Analysis

# %% [markdown]
# title

# %%
title_text = list(df['title'])
title_text_len = np.array([len(str(text).split(" ")) if text!="None" else 0 for text in title_text])
mean_title = np.mean([value for value in title_text_len if value!=0])
std_title = np.std([value for value in title_text_len if value!=0])

# %%
title_dic = Counter(title_text_len)

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(list(title_dic.values())), y=list(title_dic.keys()), name="Forums", marker_color="red"))

# Add title
fig.update_layout(
                    title_text='Title length with the mean of : ' + str(round(mean_title,2)) + " and std dev of : " + str(round(std_title,2)),
                    xaxis_title="No of Web pages",
                    yaxis_title="Title length"
        )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/length/", "title_len.pdf"), auto_open=False)
# Out:
# '../plots/forums/length/title_len.pdf.html'

# %% [markdown]
# paragraphs

# %%
paragraph_text = list(df['paragraphs'])
paragraphs_text_length = []
for paragraphs in paragraph_text:
    temp_para_len_list = []
    if paragraphs != None:
        for para in paragraphs:
            para = para.split(" ")
            temp_para_len_list.append(len(para))
    else:
        temp_para_len_list.append(0)
    paragraphs_text_length.append(temp_para_len_list)

# %%
paragraphs_text_length = np.array([item for sublist in paragraphs_text_length for item in sublist])
mean_paragraph = np.mean([value for value in paragraphs_text_length if value!=0])
std_paragraph = np.std([value for value in paragraphs_text_length if value!=0])

# %%
paragraph_dic = Counter(paragraphs_text_length)

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(list(paragraph_dic.values())), y=list(paragraph_dic.keys()), name="Forums", marker_color="red"))

# Add title
fig.update_layout(title_text='Sentence length with the mean of : ' + str(round(mean_paragraph,2)) + " and std dev of : " + str(round(std_paragraph,2)))
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/length/", "paragraphs_len.pdf"), auto_open=False)
# Out:
# '../plots/forums/length/paragraphs_len.pdf.html'

# %% [markdown]
# headings

# %%
heading_text = list(df['headings'])
headings_text_length = []
for headings in heading_text:
    temp_para_len_list = []
    if headings != None:
        for para in headings:
            para = para.split(" ")
            temp_para_len_list.append(len(para))
    else:
        temp_para_len_list.append(0)
    headings_text_length.append(temp_para_len_list)

headings_text_length = np.array([item for sublist in headings_text_length for item in sublist])
mean_heading = np.mean([value for value in headings_text_length if value!=0])
std_heading = np.std([value for value in headings_text_length if value!=0])

heading_dic = Counter(headings_text_length)

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(list(heading_dic.values())), y=list(heading_dic.keys()), name="Forums", marker_color="red"))

# Add title
fig.update_layout(title_text='Sentence length with the mean of : ' + str(round(mean_heading,2)) + " and std dev of : " + str(round(std_heading,2)))
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/length/", "headings_len.pdf"), auto_open=False)
# Out:
# '../plots/forums/length/headings_len.pdf.html'

# %% [markdown]
# Listings

# %%
listing_text = list(df['listings'])
listings_text_length = []
for listings in listing_text:
    temp_para_len_list = []
    if listings != None:
        for para in listings:
            para = para.split(" ")
            temp_para_len_list.append(len(para))
    else:
        temp_para_len_list.append(0)
    listings_text_length.append(temp_para_len_list)


listings_text_length = np.array([item for sublist in listings_text_length for item in sublist])
mean_listing = np.mean([value for value in listings_text_length if value!=0])
std_listing = np.std([value for value in listings_text_length if value!=0])

listing_dic = Counter(listings_text_length)

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(list(listing_dic.values())), y=list(listing_dic.keys()), name="Forums", marker_color="red"))

# Add title
fig.update_layout(title_text='Sentence length with the mean of : ' + str(round(mean_listing,2)) + " and std dev of : " + str(round(std_listing,2)))
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/length/", "listing_len.pdf"), auto_open=False)
# Out:
# '../plots/forums/length/listing_len.pdf.html'

# %% [markdown]
# Link text

# %%
link_text = list(df['link-text'])
links_text_length = []
for links in link_text:
    temp_para_len_list = []
    if links != None:
        for para in links:
            para = para.split(" ")
            temp_para_len_list.append(len(para))
    else:
        temp_para_len_list.append(0)
    links_text_length.append(temp_para_len_list)


links_text_length = np.array([item for sublist in links_text_length for item in sublist])
mean_link = np.mean([value for value in links_text_length if value!=0])
std_link = np.std([value for value in links_text_length if value!=0])

link_dic = Counter(links_text_length)

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(list(link_dic.values())), y=list(link_dic.keys()), name="Forums", marker_color="red"))


# Add title
fig.update_layout(title_text='Sentence length with the mean of : ' + str(round(mean_link,2)) + " and std dev of : " + str(round(std_link,2)))
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/length/", "link_len.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/length/link_len.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/length/link_len.pdf.html'

# %% [markdown]
# # Term Frequency Analysis

# %% [markdown]
# Title

# %%
title_text = list(df['title'])
title_text_tokenize = [str(title).split(" ") for title in title_text if title!="None"]

# %%
tokens = [item for sublist in title_text_tokenize for item in sublist]
tokens = list(filter(None, tokens))

analysis = FreqDist(tokens).most_common()
x, y = zip(*analysis)

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(x), y=y, name="Markets", marker_color="red"))
fig.update_layout(
                    title_text='Term Frequencies',
                    xaxis_title="Tokens",
                    yaxis_title="Frequency"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/term-frequency", "title.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/term-frequency/title.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/term-frequency/title.pdf.html'

# %% [markdown]
# Description

# %%
description_text = list(df['description'])
description_text_tokenize = []
for descriptions in description_text:
    temp_description_list = []
    if descriptions != None:
        for des in descriptions:
            des = des.split(" ")
            description_text_tokenize.append(des)
    else:
        pass

# %%
tokens = [item for sublist in description_text_tokenize for item in sublist]
tokens = list(filter(None, tokens))

# %%
analysis = FreqDist(tokens).most_common()
x, y = zip(*analysis)

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(x), y=y, name="Markets", marker_color="red"))
fig.update_layout(
                    title_text='Term Frequencies',
                    xaxis_title="Tokens",
                    yaxis_title="Frequency"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/term-frequency", "description.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/term-frequency/description.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/term-frequency/description.pdf.html'

# %% [markdown]
# Paragraphs

# %%
paragraph_text = list(df['paragraphs'])
paragraph_text_tokenize = []
for paragraphs in paragraph_text:
    temp_paragraph_list = []
    if paragraphs != None:
        for value in paragraphs:
            value = value.split(" ")
            paragraph_text_tokenize.append(value)
    else:
        pass

tokens = [item for sublist in paragraph_text_tokenize for item in sublist]
tokens = list(filter(None, tokens))

analysis = FreqDist(tokens).most_common()
x, y = zip(*analysis)

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(x), y=y, name="Markets", marker_color="red"))
fig.update_layout(
                    title_text='Term Frequencies',
                    xaxis_title="Tokens",
                    yaxis_title="Frequency"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/term-frequency", "paragraphs.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/term-frequency/paragraphs.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/term-frequency/paragraphs.pdf.html'

# %% [markdown]
# Headings

# %%
heading_text = list(df['headings'])
heading_text_tokenize = []
for headings in heading_text:
    temp_heading_list = []
    if headings != None:
        for value in headings:
            value = value.split(" ")
            heading_text_tokenize.append(value)
    else:
        pass

tokens = [item for sublist in heading_text_tokenize for item in sublist]
tokens = list(filter(None, tokens))

analysis = FreqDist(tokens).most_common()
x, y = zip(*analysis)

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(x), y=y, name="Markets", marker_color="red"))
fig.update_layout(
                    title_text='Term Frequencies',
                    xaxis_title="Tokens",
                    yaxis_title="Frequency"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/term-frequency", "headings.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/term-frequency/headings.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/term-frequency/headings.pdf.html'

# %% [markdown]
# Lisitings

# %%
listing_text = list(df['listings'])
listing_text_tokenize = []
for listings in listing_text:
    temp_listing_list = []
    if listings != None:
        for value in listings:
            value = value.split(" ")
            listing_text_tokenize.append(value)
    else:
        pass

tokens = [item for sublist in listing_text_tokenize for item in sublist]
tokens = list(filter(None, tokens))

analysis = FreqDist(tokens).most_common()
x, y = zip(*analysis)

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(x), y=y, name="Markets", marker_color="red"))
fig.update_layout(
                    title_text='Term Frequencies',
                    xaxis_title="Tokens",
                    yaxis_title="Frequency"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/term-frequency", "listings.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/term-frequency/listings.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/term-frequency/listings.pdf.html'

# %% [markdown]
# Links

# %%
link_text = list(df['link-text'])
link_text_tokenize = []
for links in link_text:
    temp_link_list = []
    if links != None:
        for value in links:
            value = value.split(" ")
            link_text_tokenize.append(value)
    else:
        pass

tokens = [item for sublist in link_text_tokenize for item in sublist]
tokens = list(filter(None, tokens))

analysis = FreqDist(tokens).most_common()
x, y = zip(*analysis)

fig = go.Figure()
fig.add_trace(go.Bar(x=np.array(x), y=y, name="Markets", marker_color="red"))
fig.update_layout(
                    title_text='Term Frequencies',
                    xaxis_title="Tokens",
                    yaxis_title="Frequency"
                    )
plotly.offline.plot(fig, filename = os.path.join("../plots/forums/term-frequency", "links.pdf"), auto_open=False)
# Out:
# /home/vageesh/.local/lib/python3.8/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `../plots/forums/term-frequency/links.pdf` didn't end with .html. Adding .html to the end of your file.
# '../plots/forums/term-frequency/links.pdf.html'
